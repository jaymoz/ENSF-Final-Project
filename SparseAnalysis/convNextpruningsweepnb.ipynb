# %%
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms

from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
import ignite.metrics
import ignite.contrib.handlers

import warnings
warnings.filterwarnings('ignore')
import sys, os
sys.path.append(os.path.abspath("../"))

import torch
import torch_pruning as tp

# %%
DATA_DIR = "./data_cn"

IMAGE_SIZE = 32

NUM_CLASSES = 10
NUM_WORKERS = 8
BATCH_SIZE = 32
EPOCHS = 100

LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-1

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("device:", DEVICE)
# Out:
# device: cuda

# %%
train_transform = transforms.Compose(
    [
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(IMAGE_SIZE, padding=4),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
    ]
)

# %%
train_dset = datasets.CIFAR10(
    root=DATA_DIR, train=True, download=True, transform=train_transform
)
test_dset = datasets.CIFAR10(
    root=DATA_DIR, train=False, download=True, transform=transforms.ToTensor()
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def dataset_show_image(dset, idx):
    X, Y = dset[idx]
    title = "Ground truth: {}".format(dset.classes[Y])
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_axis_off()
    ax.imshow(np.moveaxis(X.numpy(), 0, -1))
    ax.set_title(title)
    plt.show()

# %%
train_loader = torch.utils.data.DataLoader(
    train_dset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True,
)

test_loader = torch.utils.data.DataLoader(
    test_dset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True,
)

# %%
class LayerNormChannels(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.norm = nn.LayerNorm(channels)

    def forward(self, x):
        x = x.transpose(1, -1)
        x = self.norm(x)
        x = x.transpose(-1, 1)
        return x

# %%
class Residual(nn.Module):
    def __init__(self, *layers):
        super().__init__()
        self.residual = nn.Sequential(*layers)
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):
        return x + self.gamma * self.residual(x)

# %%
class ConvNeXtBlock(Residual):
    def __init__(self, channels, kernel_size, mult=4, p_drop=0.0):
        padding = (kernel_size - 1) // 2
        hidden_channels = channels * mult
        super().__init__(
            nn.Conv2d(
                channels, channels, kernel_size, padding=padding, groups=channels
            ),
            LayerNormChannels(channels),
            nn.Conv2d(channels, hidden_channels, 1),
            nn.GELU(),
            nn.Conv2d(hidden_channels, channels, 1),
            nn.Dropout(p_drop),
        )

# %%
class DownsampleBlock(nn.Sequential):
    def __init__(self, in_channels, out_channels, stride=2):
        super().__init__(
            LayerNormChannels(in_channels),
            nn.Conv2d(in_channels, out_channels, stride, stride=stride),
        )

# %%
class Stage(nn.Sequential):
    def __init__(self, in_channels, out_channels, num_blocks, kernel_size, p_drop=0.0):
        layers = (
            []
            if in_channels == out_channels
            else [DownsampleBlock(in_channels, out_channels)]
        )
        layers += [
            ConvNeXtBlock(out_channels, kernel_size, p_drop=p_drop)
            for _ in range(num_blocks)
        ]
        super().__init__(*layers)

# %%
class ConvNeXtBody(nn.Sequential):
    def __init__(
        self, in_channels, channel_list, num_blocks_list, kernel_size, p_drop=0.0
    ):
        layers = []
        for out_channels, num_blocks in zip(channel_list, num_blocks_list):
            layers.append(
                Stage(in_channels, out_channels, num_blocks, kernel_size, p_drop)
            )
            in_channels = out_channels
        super().__init__(*layers)

# %%
class Stem(nn.Sequential):
    def __init__(self, in_channels, out_channels, patch_size):
        super().__init__(
            nn.Conv2d(in_channels, out_channels, patch_size, stride=patch_size),
            LayerNormChannels(out_channels),
        )

# %%
class Head(nn.Sequential):
    def __init__(self, in_channels, classes):
        super().__init__(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.LayerNorm(in_channels),
            nn.Linear(in_channels, classes),
        )

# %%
class ConvNeXt(nn.Sequential):
    def __init__(
        self,
        classes,
        channel_list,
        num_blocks_list,
        kernel_size,
        patch_size,
        in_channels=3,
        res_p_drop=0.0,
    ):
        super().__init__(
            Stem(in_channels, channel_list[0], patch_size),
            ConvNeXtBody(
                channel_list[0], channel_list, num_blocks_list, kernel_size, res_p_drop
            ),
            Head(channel_list[-1], classes),
        )
        self.reset_parameters()

    def reset_parameters(self):
        for m in self.modules():
            if isinstance(m, (nn.Linear, nn.Conv2d)):
                nn.init.normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LayerNorm):
                nn.init.constant_(m.weight, 1.0)
                nn.init.zeros_(m.bias)
            elif isinstance(m, Residual):
                nn.init.zeros_(m.gamma)

    def separate_parameters(self):
        parameters_decay = set()
        parameters_no_decay = set()
        modules_weight_decay = (nn.Linear, nn.Conv2d)
        modules_no_weight_decay = (nn.LayerNorm,)

        for m_name, m in self.named_modules():
            for param_name, param in m.named_parameters():
                full_param_name = f"{m_name}.{param_name}" if m_name else param_name

                if isinstance(m, modules_no_weight_decay):
                    parameters_no_decay.add(full_param_name)
                elif param_name.endswith("bias"):
                    parameters_no_decay.add(full_param_name)
                elif isinstance(m, Residual) and param_name.endswith("gamma"):
                    parameters_no_decay.add(full_param_name)
                elif isinstance(m, modules_weight_decay):
                    parameters_decay.add(full_param_name)

        # sanity check
        assert len(parameters_decay & parameters_no_decay) == 0
        assert len(parameters_decay) + len(parameters_no_decay) == len(
            list(model.parameters())
        )

        return parameters_decay, parameters_no_decay

# %%
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: matharg (enel645). Use `wandb login --relogin` to force relogin
# True

# %%
# 2: Define the search space
sweep_configuration = {
    "method": "grid",
    "metric": {"goal": "maximize", "name": "val_acc"},
    "parameters": {
        "sparse_ratio": {"values": [0.5, 0.6, 0.7, 0.8, 0.9, 0.95]},
    },
}

sweep_id = wandb.sweep(sweep=sweep_configuration, project="pruning_analysis_convnext_v2")
# Out:
# Create sweep with ID: rydk315t
# Sweep URL: https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t

# %%
def main():
    
    run = wandb.init()
    
    class ConvNeXt(nn.Sequential):
        def __init__(
            self,
            classes,
            channel_list,
            num_blocks_list,
            kernel_size,
            patch_size,
            in_channels=3,
            res_p_drop=0.0,
        ):
            super().__init__(
                Stem(in_channels, channel_list[0], patch_size),
                ConvNeXtBody(
                    channel_list[0], channel_list, num_blocks_list, kernel_size, res_p_drop
                ),
                Head(channel_list[-1], classes),
            )
            self.reset_parameters()

        def reset_parameters(self):
            for m in self.modules():
                if isinstance(m, (nn.Linear, nn.Conv2d)):
                    nn.init.normal_(m.weight, std=0.02)
                    if m.bias is not None:
                        nn.init.zeros_(m.bias)
                elif isinstance(m, nn.LayerNorm):
                    nn.init.constant_(m.weight, 1.0)
                    nn.init.zeros_(m.bias)
                elif isinstance(m, Residual):
                    nn.init.zeros_(m.gamma)

        def separate_parameters(self):
            parameters_decay = set()
            parameters_no_decay = set()
            modules_weight_decay = (nn.Linear, nn.Conv2d)
            modules_no_weight_decay = (nn.LayerNorm,)

            for m_name, m in self.named_modules():
                for param_name, param in m.named_parameters():
                    full_param_name = f"{m_name}.{param_name}" if m_name else param_name

                    if isinstance(m, modules_no_weight_decay):
                        parameters_no_decay.add(full_param_name)
                    elif param_name.endswith("bias"):
                        parameters_no_decay.add(full_param_name)
                    elif isinstance(m, Residual) and param_name.endswith("gamma"):
                        parameters_no_decay.add(full_param_name)
                    elif isinstance(m, modules_weight_decay):
                        parameters_decay.add(full_param_name)

            # sanity check
            assert len(parameters_decay & parameters_no_decay) == 0
            assert len(parameters_decay) + len(parameters_no_decay) == len(
                list(model.parameters())
            )

            return parameters_decay, parameters_no_decay
    
    
    def get_optimizer(model, learning_rate, weight_decay):
        param_dict = {pn: p for pn, p in model.named_parameters()}
        parameters_decay, parameters_no_decay = model.separate_parameters()

        optim_groups = [
            {
                "params": [param_dict[pn] for pn in parameters_decay],
                "weight_decay": weight_decay,
            },
            {"params": [param_dict[pn] for pn in parameters_no_decay], "weight_decay": 0.0},
        ]
        optimizer = optim.AdamW(optim_groups, lr=learning_rate)
        return optimizer
    
    model = ConvNeXt(
        NUM_CLASSES,
        channel_list=[64, 128, 256, 512],
        num_blocks_list=[2, 2, 2, 2],
        kernel_size=7,
        patch_size=1,
        res_p_drop=0.0,
    )

    model.load_state_dict(torch.load('/home/athar/LeanLearn/convnext.pt'))

    model.to(DEVICE)
    
    
    
    loss = nn.CrossEntropyLoss()
    optimizer = get_optimizer(model, learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    trainer = create_supervised_trainer(model, optimizer, loss, device=DEVICE)
    lr_scheduler = optim.lr_scheduler.OneCycleLR(
        optimizer, max_lr=LEARNING_RATE, steps_per_epoch=len(train_loader), epochs=EPOCHS
    )
    trainer.add_event_handler(
        Events.ITERATION_COMPLETED, lambda engine: lr_scheduler.step()
    )
    ignite.metrics.RunningAverage(output_transform=lambda x: x).attach(trainer, "loss")
    
    val_metrics = {"accuracy": ignite.metrics.Accuracy(), "loss": ignite.metrics.Loss(loss)}
    evaluator = create_supervised_evaluator(model, metrics=val_metrics, device=DEVICE)
    history = defaultdict(list)
    
    @trainer.on(Events.EPOCH_COMPLETED)
    def log_validation_results(engine):
        train_state = engine.state
        epoch = train_state.epoch
        max_epochs = train_state.max_epochs
        train_loss = train_state.metrics["loss"]
        history["train loss"].append(train_loss)

        evaluator.run(test_loader)
        val_metrics = evaluator.state.metrics
        val_loss = val_metrics["loss"]
        val_acc = val_metrics["accuracy"]
        history["val loss"].append(val_loss)
        history["val acc"].append(val_acc)

        print(
            "{}/{} - train: loss {:.3f}; val: loss {:.3f} accuracy {:.3f}".format(
                epoch, max_epochs, train_loss, val_loss, val_acc
            )
        )
        
    
    trainer.run(train_loader, max_epochs=1)
    
    
    example_inputs = torch.rand(64, 3, 32, 32).to(DEVICE)

    # 0. importance criterion for parameter selections
    imp = tp.importance.MagnitudeImportance(p=2, group_reduction='mean')

    # 1. ignore some layers that should not be pruned, e.g., the final classifier layer.
    ignored_layers = []
    for m in model.modules():
        if isinstance(m, torch.nn.Linear) and m.out_features == 10:
            ignored_layers.append(m) # DO NOT prune the final classifier!

            
    # 2. Pruner initialization
    iterative_steps = 5 # You can prune your model to the target pruning ratio iteratively.
    pruner = tp.pruner.MagnitudePruner(
        model, 
        example_inputs, 
        global_pruning=False, # If False, a uniform ratio will be assigned to different layers.
        importance=imp, # importance criterion for parameter selection
        iterative_steps=iterative_steps, # the number of iterations to achieve target ratio
        pruning_ratio=wandb.config.sparse_ratio, # remove 50% channels, ResNet18 = {64, 128, 256, 512} => ResNet18_Half = {32, 64, 128, 256}
        ignored_layers=ignored_layers,
    )

    base_macs, base_nparams = tp.utils.count_ops_and_params(model, example_inputs)
    for i in range(iterative_steps):
        # 3. the pruner.step will remove some channels from the model with least importance
        pruner.step()
        
        # 4. Do whatever you like here, such as fintuning
        macs, nparams = tp.utils.count_ops_and_params(model, example_inputs)
        print(model)
        print(model(example_inputs).shape)
        print(
            "  Iter %d/%d, Params: %.2f M => %.2f M"
            % (i+1, iterative_steps, base_nparams / 1e6, nparams / 1e6)
        )
        print(
            "  Iter %d/%d, MACs: %.2f G => %.2f G"
            % (i+1, iterative_steps, base_macs / 1e9, macs / 1e9)
        )
        
    
    loss = nn.CrossEntropyLoss()
    optimizer = get_optimizer(model, learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    trainer = create_supervised_trainer(model, optimizer, loss, device=DEVICE)
    lr_scheduler = optim.lr_scheduler.OneCycleLR(
        optimizer, max_lr=LEARNING_RATE, steps_per_epoch=len(train_loader), epochs=EPOCHS
    )
    trainer.add_event_handler(
        Events.ITERATION_COMPLETED, lambda engine: lr_scheduler.step()
    )
    ignite.metrics.RunningAverage(output_transform=lambda x: x).attach(trainer, "loss")
    
    val_metrics = {"accuracy": ignite.metrics.Accuracy(), "loss": ignite.metrics.Loss(loss)}
    evaluator = create_supervised_evaluator(model, metrics=val_metrics, device=DEVICE)
    history = defaultdict(list)
    
    @trainer.on(Events.EPOCH_COMPLETED)
    def log_validation_results(engine):
        train_state = engine.state
        epoch = train_state.epoch
        max_epochs = train_state.max_epochs
        train_loss = train_state.metrics["loss"]
        history["train loss"].append(train_loss)

        evaluator.run(test_loader)
        val_metrics = evaluator.state.metrics
        val_loss = val_metrics["loss"]
        val_acc = val_metrics["accuracy"]
        history["val loss"].append(val_loss)
        history["val acc"].append(val_acc)

        print(
            "{}/{} - train: loss {:.3f}; val: loss {:.3f} accuracy {:.3f}".format(
                epoch, max_epochs, train_loss, val_loss, val_acc
            )
        )
        
    
    
    trainer.run(train_loader, max_epochs=10)
    
    wandb.log({"Post Pruning Acc": max(history['val acc'])})

# %%
wandb.agent(sweep_id, function=main)
# Out:
# wandb: Agent Starting Run: 62l9k7zj with config:
# wandb: 	sparse_ratio: 0.5
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/athar/LeanLearn/wandb/run-20240408_103410-62l9k7zj</code>
# Syncing run <strong><a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/62l9k7zj' target="_blank">silvery-sweep-1</a></strong> to <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t</a>
#  View project at <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2</a>
#  View sweep at <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t</a>
#  View run at <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/62l9k7zj' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/62l9k7zj</a>
# 1/1 - train: loss 0.001; val: loss 0.443 accuracy 0.915
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 57, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((57,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(57, 57, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=57)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((57,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(57, 230, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(230, 57, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(57, 57, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=57)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((57,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(57, 230, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(230, 57, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((57,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(57, 115, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(115, 115, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=115)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((115,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(115, 460, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(460, 115, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(115, 115, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=115)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((115,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(115, 460, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(460, 115, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((115,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(115, 230, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(230, 230, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=230)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((230,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(230, 921, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(921, 230, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(230, 230, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=230)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((230,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(230, 921, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(921, 230, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((230,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(230, 460, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(460, 460, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=460)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((460,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(460, 1843, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1843, 460, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(460, 460, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=460)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((460,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(460, 1843, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1843, 460, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((460,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=460, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 1/5, Params: 6.38 M => 5.16 M
#   Iter 1/5, MACs: 0.31 G => 0.25 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 51, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((51,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(51, 51, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=51)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((51,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(51, 204, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(204, 51, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(51, 51, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=51)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((51,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(51, 204, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(204, 51, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((51,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(51, 102, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(102, 102, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=102)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((102,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(102, 409, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(409, 102, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(102, 102, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=102)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((102,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(102, 409, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(409, 102, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((102,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(102, 204, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(204, 204, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=204)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((204,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(204, 819, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(819, 204, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(204, 204, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=204)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((204,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(204, 819, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(819, 204, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((204,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(204, 409, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(409, 409, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=409)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((409,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(409, 1638, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1638, 409, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(409, 409, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=409)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((409,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(409, 1638, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1638, 409, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((409,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=409, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 2/5, Params: 6.38 M => 4.09 M
#   Iter 2/5, MACs: 0.31 G => 0.20 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 44, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((44,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(44, 44, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=44)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((44,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(44, 179, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(179, 44, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(44, 44, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=44)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((44,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(44, 179, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(179, 44, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((44,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(44, 89, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(89, 89, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=89)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((89,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(89, 358, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(358, 89, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(89, 89, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=89)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((89,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(89, 358, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(358, 89, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((89,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(89, 179, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(179, 179, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=179)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((179,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(179, 716, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(716, 179, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(179, 179, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=179)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((179,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(179, 716, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(716, 179, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((179,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(179, 358, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(358, 358, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=358)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((358,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(358, 1433, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1433, 358, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(358, 358, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=358)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((358,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(358, 1433, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1433, 358, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((358,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=358, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 3/5, Params: 6.38 M => 3.14 M
#   Iter 3/5, MACs: 0.31 G => 0.15 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 38, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(38, 38, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=38)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(38, 153, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(153, 38, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(38, 38, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=38)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(38, 153, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(153, 38, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(38, 76, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(76, 76, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=76)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((76,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(76, 307, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(307, 76, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(76, 76, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=76)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((76,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(76, 307, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(307, 76, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((76,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(76, 153, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(153, 153, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=153)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((153,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(153, 614, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(614, 153, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(153, 153, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=153)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((153,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(153, 614, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(614, 153, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((153,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(153, 307, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(307, 307, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=307)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((307,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(307, 1228, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1228, 307, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(307, 307, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=307)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((307,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(307, 1228, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1228, 307, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((307,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=307, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 4/5, Params: 6.38 M => 2.32 M
#   Iter 4/5, MACs: 0.31 G => 0.11 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=32)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=32)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(32, 64, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=64)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=64)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(64, 128, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(128, 256, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 5/5, Params: 6.38 M => 1.62 M
#   Iter 5/5, MACs: 0.31 G => 0.08 G
# 1/10 - train: loss 0.519; val: loss 0.548 accuracy 0.819
# 2/10 - train: loss 0.223; val: loss 0.448 accuracy 0.861
# 3/10 - train: loss 0.161; val: loss 0.417 accuracy 0.877
# 4/10 - train: loss 0.116; val: loss 0.422 accuracy 0.881
# 5/10 - train: loss 0.097; val: loss 0.417 accuracy 0.887
# 6/10 - train: loss 0.088; val: loss 0.398 accuracy 0.890
# 7/10 - train: loss 0.116; val: loss 0.429 accuracy 0.884
# 8/10 - train: loss 0.104; val: loss 0.383 accuracy 0.893
# 9/10 - train: loss 0.135; val: loss 0.384 accuracy 0.882
# 10/10 - train: loss 0.156; val: loss 0.413 accuracy 0.883
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Post Pruning Acc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Post Pruning Acc</td><td>0.8935</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">silvery-sweep-1</strong> at: <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/62l9k7zj' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/62l9k7zj</a><br/> View project at: <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240408_103410-62l9k7zj/logs</code>
# wandb: Agent Starting Run: l1yvu5wi with config:
# wandb: 	sparse_ratio: 0.6
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/athar/LeanLearn/wandb/run-20240408_104453-l1yvu5wi</code>
# Syncing run <strong><a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/l1yvu5wi' target="_blank">silvery-sweep-2</a></strong> to <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t</a>
#  View project at <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2</a>
#  View sweep at <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/sweeps/rydk315t</a>
#  View run at <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/l1yvu5wi' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/l1yvu5wi</a>
# 1/1 - train: loss 0.001; val: loss 0.437 accuracy 0.915
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 56, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((56,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(56, 56, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=56)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((56,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(56, 225, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(225, 56, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(56, 56, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=56)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((56,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(56, 225, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(225, 56, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((56,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(56, 112, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(112, 112, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=112)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((112,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(112, 450, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(450, 112, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(112, 112, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=112)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((112,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(112, 450, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(450, 112, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((112,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(112, 225, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(225, 225, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=225)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((225,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(225, 901, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(901, 225, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(225, 225, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=225)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((225,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(225, 901, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(901, 225, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((225,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(225, 450, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(450, 450, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=450)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((450,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(450, 1802, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1802, 450, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(450, 450, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=450)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((450,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(450, 1802, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1802, 450, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((450,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=450, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 1/5, Params: 6.38 M => 4.94 M
#   Iter 1/5, MACs: 0.31 G => 0.24 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 48, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(48, 194, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(194, 48, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(48, 194, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(194, 48, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(48, 97, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(97, 97, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=97)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((97,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(97, 389, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(389, 97, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(97, 97, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=97)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((97,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(97, 389, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(389, 97, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((97,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(97, 194, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(194, 194, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=194)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((194,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(194, 778, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(778, 194, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(194, 194, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=194)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((194,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(194, 778, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(778, 194, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((194,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(194, 389, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(389, 389, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=389)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((389,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(389, 1556, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1556, 389, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(389, 389, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=389)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((389,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(389, 1556, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1556, 389, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((389,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=389, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 2/5, Params: 6.38 M => 3.70 M
#   Iter 2/5, MACs: 0.31 G => 0.18 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 40, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(40, 40, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=40)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(40, 163, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(163, 40, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(40, 40, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=40)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(40, 163, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(163, 40, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(40, 81, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(81, 81, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=81)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((81,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(81, 327, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(327, 81, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(81, 81, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=81)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((81,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(81, 327, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(327, 81, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((81,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(81, 163, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(163, 163, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=163)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((163,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(163, 655, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(655, 163, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(163, 163, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=163)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((163,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(163, 655, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(655, 163, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((163,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(163, 327, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(327, 327, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=327)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((327,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(327, 1310, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1310, 327, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(327, 327, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=327)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((327,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(327, 1310, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(1310, 327, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((327,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=327, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 3/5, Params: 6.38 M => 2.63 M
#   Iter 3/5, MACs: 0.31 G => 0.13 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 33, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((33,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(33, 33, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=33)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((33,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(33, 133, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(133, 33, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
# ...
#           )
#           (2): Conv2d(55, 220, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(220, 55, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(55, 55, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=55)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((55,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(55, 220, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(220, 55, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((55,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(55, 110, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(110, 110, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=110)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((110,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(110, 440, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(440, 110, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(110, 110, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=110)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((110,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(110, 440, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(440, 110, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((110,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(110, 220, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(220, 220, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=220)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((220,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(220, 880, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(880, 220, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(220, 220, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=220)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((220,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(220, 880, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(880, 220, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((220,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=220, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 3/5, Params: 6.38 M => 1.21 M
#   Iter 3/5, MACs: 0.31 G => 0.06 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 15, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((15,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(15, 15, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=15)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((15,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(15, 61, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(61, 15, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(15, 15, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=15)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((15,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(15, 61, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(61, 15, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((15,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(15, 30, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(30, 30, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=30)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((30,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(30, 122, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(122, 30, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(30, 30, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=30)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((30,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(30, 122, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(122, 30, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((30,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(30, 61, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(61, 61, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=61)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((61,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(61, 245, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(245, 61, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(61, 61, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=61)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((61,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(61, 245, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(245, 61, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((61,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(61, 122, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(122, 122, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=122)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((122,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(122, 491, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(491, 122, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(122, 122, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=122)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((122,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(122, 491, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(491, 122, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((122,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=122, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 4/5, Params: 6.38 M => 0.38 M
#   Iter 4/5, MACs: 0.31 G => 0.02 G
# ConvNeXt(
#   (0): Stem(
#     (0): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (1): LayerNormChannels(
#       (norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (1): ConvNeXtBody(
#     (0): Stage(
#       (0): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(3, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=3)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(3, 12, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(12, 3, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(3, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=3)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(3, 12, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(12, 3, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(3, 6, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(6, 6, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=6)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((6,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(6, 25, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(25, 6, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(6, 6, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=6)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((6,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(6, 25, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(25, 6, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((6,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(6, 12, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(12, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=12)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(12, 51, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(51, 12, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(12, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=12)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(12, 51, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(51, 12, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): Stage(
#       (0): DownsampleBlock(
#         (0): LayerNormChannels(
#           (norm): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Conv2d(12, 25, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (1): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(25, 25, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=25)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((25,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(25, 102, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(102, 25, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): ConvNeXtBlock(
#         (residual): Sequential(
#           (0): Conv2d(25, 25, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=25)
#           (1): LayerNormChannels(
#             (norm): LayerNorm((25,), eps=1e-05, elementwise_affine=True)
#           )
#           (2): Conv2d(25, 102, kernel_size=(1, 1), stride=(1, 1))
#           (3): GELU(approximate='none')
#           (4): Conv2d(102, 25, kernel_size=(1, 1), stride=(1, 1))
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): Head(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((25,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=25, out_features=10, bias=True)
#   )
# )
# torch.Size([64, 10])
#   Iter 5/5, Params: 6.38 M => 0.02 M
#   Iter 5/5, MACs: 0.31 G => 0.00 G
# 1/10 - train: loss 2.127; val: loss 2.103 accuracy 0.191
# 2/10 - train: loss 2.016; val: loss 2.040 accuracy 0.212
# 3/10 - train: loss 2.000; val: loss 1.986 accuracy 0.225
# 4/10 - train: loss 1.956; val: loss 1.963 accuracy 0.225
# 5/10 - train: loss 1.964; val: loss 1.977 accuracy 0.222
# 6/10 - train: loss 1.940; val: loss 1.916 accuracy 0.250
# 7/10 - train: loss 1.927; val: loss 1.933 accuracy 0.245
# 8/10 - train: loss 1.896; val: loss 1.870 accuracy 0.277
# 9/10 - train: loss 1.867; val: loss 1.850 accuracy 0.290
# 10/10 - train: loss 1.856; val: loss 1.857 accuracy 0.291
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Post Pruning Acc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Post Pruning Acc</td><td>0.2912</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dandy-sweep-6</strong> at: <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/ox2a667r' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2/runs/ox2a667r</a><br/> View project at: <a href='https://wandb.ai/enel645/pruning_analysis_convnext_v2' target="_blank">https://wandb.ai/enel645/pruning_analysis_convnext_v2</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240408_112635-ox2a667r/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
